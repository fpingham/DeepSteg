# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
# Directory path
os.chdir("..")
cwd = 'input'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/output/models/'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/sample/valid/'
TRAIN_PATH = cwd+'/sample/train/'
TEST_PATH = cwd+'/test/'

if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %% [markdown]
# Set of useful functions we are going to need

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %% [markdown]
# The author used 3x3, 4x4 and 5x5 each for the first four layers and the concatenated them and passed them to the final layer.
#
# This architecture was replicated exactly in each of the layers. Output of PrepNetwork (secret image preapred to merge with cover) is concatenated to the cover and fed into the hidding network. The hidding network hides the secret image in the PrepNetwork's output and returns the hidden image. This is fed into the Reveal network to output the message, that should be close to the secret image.

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %% [markdown]
# We create loaders for normalized training, validation and test sets

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %% [markdown]
# We train the model and validate it, saving the best model. We use Adam as an optimizer as the paper specifies.

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            train_losses.append(train_loss.data[0])
            loss_history.append(train_loss.data[0])
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data[0], train_loss_cover.data[0], train_loss_secret.data[0]))
    
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# Training: Batch 1/66. Loss of 3.1918, cover loss of 1.6364, secret loss of 1.5554
# Training: Batch 2/66. Loss of 3.6420, cover loss of 1.1539, secret loss of 2.4880
# Training: Batch 3/66. Loss of 3.2181, cover loss of 1.2495, secret loss of 1.9685
# Training: Batch 4/66. Loss of 2.1135, cover loss of 1.2394, secret loss of 0.8741
# Training: Batch 5/66. Loss of 2.0391, cover loss of 1.1773, secret loss of 0.8618
# Training: Batch 6/66. Loss of 1.9373, cover loss of 0.6081, secret loss of 1.3292
# Training: Batch 7/66. Loss of 4.1220, cover loss of 0.5117, secret loss of 3.6103
# Training: Batch 8/66. Loss of 1.4557, cover loss of 1.0503, secret loss of 0.4054
# Training: Batch 9/66. Loss of 6.2450, cover loss of 4.7624, secret loss of 1.4826
# Training: Batch 10/66. Loss of 3.8425, cover loss of 1.9310, secret loss of 1.9115
# Training: Batch 11/66. Loss of 4.3488, cover loss of 2.5160, secret loss of 1.8328
# Training: Batch 12/66. Loss of 2.9593, cover loss of 1.5212, secret loss of 1.4381
# Training: Batch 13/66. Loss of 3.1453, cover loss of 0.9554, secret loss of 2.1900
# Training: Batch 14/66. Loss of 2.5651, cover loss of 1.6030, secret loss of 0.9621
# Training: Batch 15/66. Loss of 3.2294, cover loss of 1.2311, secret loss of 1.9983
# Training: Batch 16/66. Loss of 1.3567, cover loss of 0.4366, secret loss of 0.9201
# Training: Batch 17/66. Loss of 2.4299, cover loss of 0.7692, secret loss of 1.6607
# Training: Batch 18/66. Loss of 4.2575, cover loss of 1.8948, secret loss of 2.3627
# Training: Batch 19/66. Loss of 1.6425, cover loss of 0.6305, secret loss of 1.0120
# Training: Batch 20/66. Loss of 1.2961, cover loss of 0.5074, secret loss of 0.7887
# Training: Batch 21/66. Loss of 1.2641, cover loss of 0.5393, secret loss of 0.7248
# Training: Batch 22/66. Loss of 2.1934, cover loss of 0.4477, secret loss of 1.7457
# Training: Batch 23/66. Loss of 0.8517, cover loss of 0.4684, secret loss of 0.3833
# Training: Batch 24/66. Loss of 2.0836, cover loss of 0.8175, secret loss of 1.2660
# Training: Batch 25/66. Loss of 1.4129, cover loss of 0.7082, secret loss of 0.7047
# Training: Batch 26/66. Loss of 4.1377, cover loss of 2.2021, secret loss of 1.9356
# Training: Batch 27/66. Loss of 0.7357, cover loss of 0.3304, secret loss of 0.4053
# Training: Batch 28/66. Loss of 1.6090, cover loss of 0.6976, secret loss of 0.9113
# Training: Batch 29/66. Loss of 4.2685, cover loss of 1.9737, secret loss of 2.2949
# Training: Batch 30/66. Loss of 3.6616, cover loss of 1.3343, secret loss of 2.3273
# Training: Batch 31/66. Loss of 2.4705, cover loss of 0.9616, secret loss of 1.5089
# Training: Batch 32/66. Loss of 2.2954, cover loss of 1.0944, secret loss of 1.2010
# Training: Batch 33/66. Loss of 5.1166, cover loss of 1.0613, secret loss of 4.0553
# Training: Batch 34/66. Loss of 2.4366, cover loss of 0.6448, secret loss of 1.7917
# Training: Batch 35/66. Loss of 3.5452, cover loss of 0.2301, secret loss of 3.3150
# Training: Batch 36/66. Loss of 1.7733, cover loss of 0.6759, secret loss of 1.0974
# Training: Batch 37/66. Loss of 1.9497, cover loss of 0.7229, secret loss of 1.2268
# Training: Batch 38/66. Loss of 0.6415, cover loss of 0.1950, secret loss of 0.4465
# Training: Batch 39/66. Loss of 1.7518, cover loss of 0.4344, secret loss of 1.3174
# Training: Batch 40/66. Loss of 2.0371, cover loss of 0.2381, secret loss of 1.7991
# Training: Batch 41/66. Loss of 1.5618, cover loss of 0.5080, secret loss of 1.0538
# Training: Batch 42/66. Loss of 1.9037, cover loss of 0.3703, secret loss of 1.5333
# Training: Batch 43/66. Loss of 1.1884, cover loss of 0.7786, secret loss of 0.4098
# Training: Batch 44/66. Loss of 2.5564, cover loss of 0.7894, secret loss of 1.7670
# Training: Batch 45/66. Loss of 2.0191, cover loss of 0.5348, secret loss of 1.4842
# Training: Batch 46/66. Loss of 4.9888, cover loss of 3.0733, secret loss of 1.9155
# Training: Batch 47/66. Loss of 1.9622, cover loss of 0.7789, secret loss of 1.1834
# Training: Batch 48/66. Loss of 1.9416, cover loss of 0.8981, secret loss of 1.0435
# Training: Batch 49/66. Loss of 1.9864, cover loss of 0.4165, secret loss of 1.5699
# Training: Batch 50/66. Loss of 2.4666, cover loss of 0.3803, secret loss of 2.0863
# Training: Batch 51/66. Loss of 2.0565, cover loss of 0.5716, secret loss of 1.4849
# Training: Batch 52/66. Loss of 3.5194, cover loss of 1.4276, secret loss of 2.0918
# Training: Batch 53/66. Loss of 1.2475, cover loss of 0.3930, secret loss of 0.8545
# Training: Batch 54/66. Loss of 1.5155, cover loss of 0.5401, secret loss of 0.9754
# Training: Batch 55/66. Loss of 1.9225, cover loss of 0.7089, secret loss of 1.2135
# Training: Batch 56/66. Loss of 2.5069, cover loss of 0.5463, secret loss of 1.9607
# Training: Batch 57/66. Loss of 2.1973, cover loss of 0.2256, secret loss of 1.9717
# Training: Batch 58/66. Loss of 3.9597, cover loss of 0.3295, secret loss of 3.6301
# Training: Batch 59/66. Loss of 3.0629, cover loss of 1.0324, secret loss of 2.0305
# Training: Batch 60/66. Loss of 0.7673, cover loss of 0.1997, secret loss of 0.5676
# Training: Batch 61/66. Loss of 2.5200, cover loss of 0.2514, secret loss of 2.2686
# Training: Batch 62/66. Loss of 2.7875, cover loss of 0.6156, secret loss of 2.1719
# Training: Batch 63/66. Loss of 1.2118, cover loss of 0.1652, secret loss of 1.0466
# Training: Batch 64/66. Loss of 2.0627, cover loss of 0.7898, secret loss of 1.2730
# Training: Batch 65/66. Loss of 1.3404, cover loss of 0.1928, secret loss of 1.1476
# Training: Batch 66/66. Loss of 0.9579, cover loss of 0.0980, secret loss of 0.8600
# Epoch [1/3], Average_loss: 2.4467
# Training: Batch 1/66. Loss of 1.1232, cover loss of 0.2030, secret loss of 0.9202
# Training: Batch 2/66. Loss of 1.5720, cover loss of 0.3514, secret loss of 1.2206
# Training: Batch 3/66. Loss of 1.2965, cover loss of 0.2393, secret loss of 1.0572
# Training: Batch 4/66. Loss of 2.3842, cover loss of 0.2786, secret loss of 2.1056
# Training: Batch 5/66. Loss of 4.9484, cover loss of 0.3564, secret loss of 4.5919
# Training: Batch 6/66. Loss of 1.0704, cover loss of 0.2017, secret loss of 0.8687
# Training: Batch 7/66. Loss of 3.7645, cover loss of 0.1783, secret loss of 3.5861
# Training: Batch 8/66. Loss of 1.1406, cover loss of 0.3721, secret loss of 0.7686
# Training: Batch 9/66. Loss of 5.1466, cover loss of 0.1363, secret loss of 5.0103
# Training: Batch 10/66. Loss of 1.9713, cover loss of 0.2219, secret loss of 1.7493
# Training: Batch 11/66. Loss of 2.3212, cover loss of 0.1665, secret loss of 2.1546
# Training: Batch 12/66. Loss of 1.3581, cover loss of 0.1781, secret loss of 1.1800
# Training: Batch 13/66. Loss of 0.9350, cover loss of 0.1941, secret loss of 0.7409
# Training: Batch 14/66. Loss of 3.9000, cover loss of 0.1425, secret loss of 3.7575
# Training: Batch 15/66. Loss of 1.6272, cover loss of 0.2167, secret loss of 1.4105
# Training: Batch 16/66. Loss of 3.6519, cover loss of 0.1696, secret loss of 3.4822
# Training: Batch 17/66. Loss of 0.8085, cover loss of 0.1209, secret loss of 0.6877
# Training: Batch 18/66. Loss of 1.6590, cover loss of 0.1695, secret loss of 1.4895
# Training: Batch 19/66. Loss of 1.7370, cover loss of 0.2303, secret loss of 1.5067
# Training: Batch 20/66. Loss of 1.6345, cover loss of 0.1771, secret loss of 1.4574
# Training: Batch 21/66. Loss of 2.2216, cover loss of 0.2999, secret loss of 1.9217
# Training: Batch 22/66. Loss of 2.4736, cover loss of 0.1584, secret loss of 2.3151
# Training: Batch 23/66. Loss of 1.4836, cover loss of 0.1227, secret loss of 1.3610
# Training: Batch 24/66. Loss of 0.9543, cover loss of 0.3855, secret loss of 0.5688
# Training: Batch 25/66. Loss of 1.7163, cover loss of 0.7709, secret loss of 0.9454
# Training: Batch 26/66. Loss of 1.3297, cover loss of 0.2008, secret loss of 1.1289
# Training: Batch 27/66. Loss of 2.3081, cover loss of 0.2356, secret loss of 2.0726
# Training: Batch 28/66. Loss of 1.0113, cover loss of 0.2277, secret loss of 0.7836
# Training: Batch 29/66. Loss of 1.4306, cover loss of 0.1194, secret loss of 1.3112
# Training: Batch 30/66. Loss of 3.7807, cover loss of 0.1462, secret loss of 3.6345
# Training: Batch 31/66. Loss of 2.4332, cover loss of 0.1413, secret loss of 2.2919
# Training: Batch 32/66. Loss of 3.5274, cover loss of 0.2120, secret loss of 3.3154
# Training: Batch 33/66. Loss of 1.2500, cover loss of 0.3974, secret loss of 0.8526
# Training: Batch 34/66. Loss of 1.8557, cover loss of 0.2735, secret loss of 1.5822
# Training: Batch 35/66. Loss of 1.2205, cover loss of 0.2337, secret loss of 0.9868
# Training: Batch 36/66. Loss of 3.1222, cover loss of 0.2302, secret loss of 2.8920
# Training: Batch 37/66. Loss of 1.2130, cover loss of 0.1169, secret loss of 1.0961
# Training: Batch 38/66. Loss of 1.2133, cover loss of 0.4759, secret loss of 0.7374
# Training: Batch 39/66. Loss of 0.7221, cover loss of 0.1511, secret loss of 0.5710
# Training: Batch 40/66. Loss of 2.6178, cover loss of 0.5779, secret loss of 2.0399
# Training: Batch 41/66. Loss of 1.2241, cover loss of 0.1560, secret loss of 1.0681
# Training: Batch 42/66. Loss of 2.1574, cover loss of 0.5959, secret loss of 1.5615
# Training: Batch 43/66. Loss of 2.6219, cover loss of 0.5219, secret loss of 2.1000
# Training: Batch 44/66. Loss of 1.5573, cover loss of 0.1312, secret loss of 1.4260
# Training: Batch 45/66. Loss of 2.1515, cover loss of 0.1938, secret loss of 1.9577
# Training: Batch 46/66. Loss of 3.3487, cover loss of 0.0903, secret loss of 3.2584
# Training: Batch 47/66. Loss of 1.5178, cover loss of 0.4604, secret loss of 1.0575
# Training: Batch 48/66. Loss of 1.2625, cover loss of 0.2523, secret loss of 1.0102
# Training: Batch 49/66. Loss of 1.3819, cover loss of 0.4774, secret loss of 0.9045
# Training: Batch 50/66. Loss of 0.5600, cover loss of 0.1811, secret loss of 0.3789
# Training: Batch 51/66. Loss of 1.1858, cover loss of 0.2913, secret loss of 0.8945
# Training: Batch 52/66. Loss of 1.5049, cover loss of 0.4012, secret loss of 1.1037
# Training: Batch 53/66. Loss of 1.4940, cover loss of 0.2311, secret loss of 1.2630
# Training: Batch 54/66. Loss of 1.8820, cover loss of 0.3952, secret loss of 1.4867
# Training: Batch 55/66. Loss of 1.0989, cover loss of 0.1673, secret loss of 0.9316
# Training: Batch 56/66. Loss of 1.8850, cover loss of 0.2393, secret loss of 1.6457
# Training: Batch 57/66. Loss of 2.4592, cover loss of 0.2724, secret loss of 2.1868
# Training: Batch 58/66. Loss of 2.1397, cover loss of 0.2005, secret loss of 1.9393
# Training: Batch 59/66. Loss of 0.5624, cover loss of 0.2598, secret loss of 0.3026
# Training: Batch 60/66. Loss of 0.5174, cover loss of 0.1633, secret loss of 0.3541
# Training: Batch 61/66. Loss of 0.9035, cover loss of 0.1735, secret loss of 0.7300
# Training: Batch 62/66. Loss of 1.7384, cover loss of 0.3116, secret loss of 1.4268
# Training: Batch 63/66. Loss of 0.5802, cover loss of 0.0778, secret loss of 0.5023
# Training: Batch 64/66. Loss of 3.3593, cover loss of 0.5911, secret loss of 2.7682
# Training: Batch 65/66. Loss of 1.6237, cover loss of 0.1953, secret loss of 1.4284
# Training: Batch 66/66. Loss of 2.1439, cover loss of 0.1758, secret loss of 1.9681
# Epoch [2/3], Average_loss: 1.8909
# Training: Batch 1/66. Loss of 1.6997, cover loss of 0.2018, secret loss of 1.4980
# Training: Batch 2/66. Loss of 1.7717, cover loss of 0.0895, secret loss of 1.6822
# Training: Batch 3/66. Loss of 0.9263, cover loss of 0.1096, secret loss of 0.8168
# Training: Batch 4/66. Loss of 3.1427, cover loss of 2.8295, secret loss of 0.3131
# Training: Batch 5/66. Loss of 1.5480, cover loss of 0.5474, secret loss of 1.0006
# Training: Batch 6/66. Loss of 1.5351, cover loss of 0.6546, secret loss of 0.8804
# Training: Batch 7/66. Loss of 2.0107, cover loss of 0.6570, secret loss of 1.3536
# Training: Batch 8/66. Loss of 1.4587, cover loss of 0.2467, secret loss of 1.2120
# Training: Batch 9/66. Loss of 1.9696, cover loss of 0.2854, secret loss of 1.6842
# Training: Batch 10/66. Loss of 1.4584, cover loss of 0.1810, secret loss of 1.2775
# Training: Batch 11/66. Loss of 3.2397, cover loss of 0.1520, secret loss of 3.0877
# Training: Batch 12/66. Loss of 5.1900, cover loss of 0.7012, secret loss of 4.4888
# Training: Batch 13/66. Loss of 1.3610, cover loss of 0.1460, secret loss of 1.2151
# Training: Batch 14/66. Loss of 2.4251, cover loss of 0.2090, secret loss of 2.2160
# Training: Batch 15/66. Loss of 1.5396, cover loss of 0.1086, secret loss of 1.4310
# Training: Batch 16/66. Loss of 1.7671, cover loss of 0.1065, secret loss of 1.6607
# Training: Batch 17/66. Loss of 1.4636, cover loss of 0.2971, secret loss of 1.1665
# Training: Batch 18/66. Loss of 1.8219, cover loss of 0.3453, secret loss of 1.4765
# Training: Batch 19/66. Loss of 1.9068, cover loss of 0.3352, secret loss of 1.5716
# Training: Batch 20/66. Loss of 3.4266, cover loss of 0.2033, secret loss of 3.2233
# Training: Batch 21/66. Loss of 0.7622, cover loss of 0.0887, secret loss of 0.6734
# Training: Batch 22/66. Loss of 2.5029, cover loss of 0.4927, secret loss of 2.0102
# Training: Batch 23/66. Loss of 1.3051, cover loss of 0.2679, secret loss of 1.0372
# Training: Batch 24/66. Loss of 2.2508, cover loss of 0.0908, secret loss of 2.1601
# Training: Batch 25/66. Loss of 1.2713, cover loss of 0.6949, secret loss of 0.5764
# Training: Batch 26/66. Loss of 1.6050, cover loss of 0.1621, secret loss of 1.4430
# Training: Batch 27/66. Loss of 5.1755, cover loss of 0.2511, secret loss of 4.9243
# Training: Batch 28/66. Loss of 1.6759, cover loss of 0.1847, secret loss of 1.4913
# Training: Batch 29/66. Loss of 1.8865, cover loss of 0.0492, secret loss of 1.8373
# Training: Batch 30/66. Loss of 1.1702, cover loss of 0.5079, secret loss of 0.6623
# Training: Batch 31/66. Loss of 1.3485, cover loss of 0.2603, secret loss of 1.0882
# Training: Batch 32/66. Loss of 2.6083, cover loss of 0.3631, secret loss of 2.2452
# Training: Batch 33/66. Loss of 1.6622, cover loss of 0.1234, secret loss of 1.5388
# Training: Batch 34/66. Loss of 1.5668, cover loss of 0.1572, secret loss of 1.4097
# Training: Batch 35/66. Loss of 1.5904, cover loss of 0.1017, secret loss of 1.4887
# Training: Batch 36/66. Loss of 1.4339, cover loss of 0.2763, secret loss of 1.1576
# Training: Batch 37/66. Loss of 0.9828, cover loss of 0.1506, secret loss of 0.8321
# Training: Batch 38/66. Loss of 0.6293, cover loss of 0.0915, secret loss of 0.5378
# Training: Batch 39/66. Loss of 1.6701, cover loss of 0.0875, secret loss of 1.5826
# Training: Batch 40/66. Loss of 1.3840, cover loss of 0.0893, secret loss of 1.2947
# Training: Batch 41/66. Loss of 1.9315, cover loss of 0.2552, secret loss of 1.6764
# Training: Batch 42/66. Loss of 1.9270, cover loss of 0.1546, secret loss of 1.7724
# Training: Batch 43/66. Loss of 0.4240, cover loss of 0.1470, secret loss of 0.2770
# Training: Batch 44/66. Loss of 0.7099, cover loss of 0.1437, secret loss of 0.5662
# Training: Batch 45/66. Loss of 2.4132, cover loss of 0.2854, secret loss of 2.1278
# Training: Batch 46/66. Loss of 1.1874, cover loss of 0.2852, secret loss of 0.9023
# Training: Batch 47/66. Loss of 1.0292, cover loss of 0.2008, secret loss of 0.8284
# Training: Batch 48/66. Loss of 1.4952, cover loss of 0.2475, secret loss of 1.2476
# Training: Batch 49/66. Loss of 2.2652, cover loss of 0.1514, secret loss of 2.1138
# Training: Batch 50/66. Loss of 2.1812, cover loss of 0.0908, secret loss of 2.0904
# Training: Batch 51/66. Loss of 0.6021, cover loss of 0.1885, secret loss of 0.4137
# Training: Batch 52/66. Loss of 1.1875, cover loss of 0.1213, secret loss of 1.0663
# Training: Batch 53/66. Loss of 1.9238, cover loss of 0.2583, secret loss of 1.6656
# Training: Batch 54/66. Loss of 1.0837, cover loss of 0.1361, secret loss of 0.9477
# Training: Batch 55/66. Loss of 0.6337, cover loss of 0.1989, secret loss of 0.4348
# Training: Batch 56/66. Loss of 4.1971, cover loss of 0.7945, secret loss of 3.4026
# Training: Batch 57/66. Loss of 1.0025, cover loss of 0.3742, secret loss of 0.6282
# Training: Batch 58/66. Loss of 0.8044, cover loss of 0.4493, secret loss of 0.3551
# Training: Batch 59/66. Loss of 0.7728, cover loss of 0.1179, secret loss of 0.6550
# Training: Batch 60/66. Loss of 1.4239, cover loss of 0.2411, secret loss of 1.1828
# Training: Batch 61/66. Loss of 1.6413, cover loss of 0.1912, secret loss of 1.4501
# Training: Batch 62/66. Loss of 1.1819, cover loss of 0.1494, secret loss of 1.0325
# Training: Batch 63/66. Loss of 1.4361, cover loss of 0.4175, secret loss of 1.0187
# Training: Batch 64/66. Loss of 0.9626, cover loss of 0.1123, secret loss of 0.8502
# Training: Batch 65/66. Loss of 0.8913, cover loss of 0.1291, secret loss of 0.7623
# Training: Batch 66/66. Loss of 1.3431, cover loss of 0.0924, secret loss of 1.2507
# Epoch [3/3], Average_loss: 1.7090

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %% [markdown]
# We test the model and print out a few images so we can visually see how good a job the model did.

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data[0], loss_secret.data[0], loss_cover.data[0]))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.data[0])
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# Total loss: 1.28
# Loss on secret: 1.12
# Loss on cover: 0.16
# Total loss: 1.59
# Loss on secret: 1.53
# Loss on cover: 0.06
# Total loss: 1.82
# Loss on secret: 1.77
# Loss on cover: 0.05
# Total loss: 3.95
# Loss on secret: 3.78
# Loss on cover: 0.17
