# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
# Directory path
os.chdir("..")
cwd = 'input'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 3

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/output/models/'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
VALID_PATH = cwd+'/sample/valid/'
TRAIN_PATH = cwd+'/sample/train/'
TEST_PATH = cwd+'/test/'

if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %% [markdown]
# Set of useful functions we are going to need

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.Tensor(tensor.size()).uniform_(mean, stddev)
    return Variable(tensor + noise)

# %% [markdown]
# The author used 3x3, 4x4 and 5x5 each for the first four layers and the concatenated them and passed them to the final layer.
#
# This architecture was replicated exactly in each of the layers. Output of PrepNetwork (secret image preapred to merge with cover) is concatenated to the cover and fed into the hidding network. The hidding network hides the secret image in the PrepNetwork's output and returns the hidden image. This is fed into the Reveal network to output the message, that should be close to the secret image.

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %% [markdown]
# We create loaders for normalized training, validation and test sets

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates validation set
val_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        VALID_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)


# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# %% [markdown]
# We train the model and validate it, saving the best model. We use Adam as an optimizer as the paper specifies.

# %%
def train_model(train_loader, val_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            train_losses.append(train_loss.data[0])
            loss_history.append(train_loss.data[0])
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data[0], train_loss_cover.data[0], train_loss_secret.data[0]))
    
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, val_loader, beta, learning_rate)
# Out:
# Training: Batch 1/66. Loss of 3.0867, cover loss of 0.3610, secret loss of 0.9086
# Training: Batch 2/66. Loss of 8.7020, cover loss of 3.2708, secret loss of 1.8104
# Training: Batch 3/66. Loss of 7.0890, cover loss of 0.7606, secret loss of 2.1095
# Training: Batch 4/66. Loss of 3.3360, cover loss of 1.5755, secret loss of 0.5868
# Training: Batch 5/66. Loss of 10.4880, cover loss of 0.7417, secret loss of 3.2488
# Training: Batch 6/66. Loss of 4.4943, cover loss of 1.9403, secret loss of 0.8514
# Training: Batch 7/66. Loss of 4.4730, cover loss of 0.9547, secret loss of 1.1727
# Training: Batch 8/66. Loss of 16.3788, cover loss of 1.3788, secret loss of 5.0000
# Training: Batch 9/66. Loss of 6.8222, cover loss of 1.4704, secret loss of 1.7839
# Training: Batch 10/66. Loss of 3.5560, cover loss of 1.1836, secret loss of 0.7908
# Training: Batch 11/66. Loss of 2.6267, cover loss of 1.1228, secret loss of 0.5013
# Training: Batch 12/66. Loss of 3.3469, cover loss of 1.5307, secret loss of 0.6054
# Training: Batch 13/66. Loss of 14.8234, cover loss of 3.1349, secret loss of 3.8962
# Training: Batch 14/66. Loss of 3.7988, cover loss of 1.8706, secret loss of 0.6427
# Training: Batch 15/66. Loss of 4.6881, cover loss of 1.0350, secret loss of 1.2177
# Training: Batch 16/66. Loss of 4.8194, cover loss of 1.3709, secret loss of 1.1495
# Training: Batch 17/66. Loss of 7.5714, cover loss of 1.1114, secret loss of 2.1533
# Training: Batch 18/66. Loss of 7.5966, cover loss of 1.5067, secret loss of 2.0300
# Training: Batch 19/66. Loss of 7.4585, cover loss of 0.8501, secret loss of 2.2028
# Training: Batch 20/66. Loss of 3.6479, cover loss of 1.5801, secret loss of 0.6893
# Training: Batch 21/66. Loss of 6.5362, cover loss of 2.3395, secret loss of 1.3989
# Training: Batch 22/66. Loss of 3.5672, cover loss of 0.9615, secret loss of 0.8686
# Training: Batch 23/66. Loss of 4.7007, cover loss of 1.0341, secret loss of 1.2222
# Training: Batch 24/66. Loss of 6.1971, cover loss of 1.7571, secret loss of 1.4800
# Training: Batch 25/66. Loss of 4.4890, cover loss of 0.1573, secret loss of 1.4439
# Training: Batch 26/66. Loss of 1.7823, cover loss of 0.4923, secret loss of 0.4300
# Training: Batch 27/66. Loss of 5.5577, cover loss of 0.2721, secret loss of 1.7619
# Training: Batch 28/66. Loss of 4.7918, cover loss of 0.2555, secret loss of 1.5121
# Training: Batch 29/66. Loss of 5.9144, cover loss of 0.3232, secret loss of 1.8637
# Training: Batch 30/66. Loss of 3.2362, cover loss of 0.4145, secret loss of 0.9406
# Training: Batch 31/66. Loss of 10.8072, cover loss of 1.1002, secret loss of 3.2356
# Training: Batch 32/66. Loss of 14.2215, cover loss of 3.8057, secret loss of 3.4719
# Training: Batch 33/66. Loss of 10.3289, cover loss of 0.2298, secret loss of 3.3664
# Training: Batch 34/66. Loss of 1.8530, cover loss of 0.5612, secret loss of 0.4306
# Training: Batch 35/66. Loss of 5.0764, cover loss of 1.1331, secret loss of 1.3144
# Training: Batch 36/66. Loss of 4.2087, cover loss of 1.2833, secret loss of 0.9751
# Training: Batch 37/66. Loss of 2.0043, cover loss of 0.6051, secret loss of 0.4664
# Training: Batch 38/66. Loss of 5.2390, cover loss of 0.8052, secret loss of 1.4779
# Training: Batch 39/66. Loss of 4.7583, cover loss of 0.6322, secret loss of 1.3754
# Training: Batch 40/66. Loss of 4.6282, cover loss of 0.7545, secret loss of 1.2912
# Training: Batch 41/66. Loss of 5.2561, cover loss of 0.2601, secret loss of 1.6653
# Training: Batch 42/66. Loss of 5.9202, cover loss of 1.2432, secret loss of 1.5590
# Training: Batch 43/66. Loss of 4.7375, cover loss of 0.6413, secret loss of 1.3654
# Training: Batch 44/66. Loss of 4.4162, cover loss of 0.6980, secret loss of 1.2394
# Training: Batch 45/66. Loss of 6.2254, cover loss of 0.5556, secret loss of 1.8899
# Training: Batch 46/66. Loss of 2.9304, cover loss of 0.2740, secret loss of 0.8855
# Training: Batch 47/66. Loss of 3.1623, cover loss of 0.9343, secret loss of 0.7427
# Training: Batch 48/66. Loss of 5.2421, cover loss of 1.6082, secret loss of 1.2113
# Training: Batch 49/66. Loss of 4.8622, cover loss of 0.4647, secret loss of 1.4658
# Training: Batch 50/66. Loss of 7.7286, cover loss of 0.4594, secret loss of 2.4231
# Training: Batch 51/66. Loss of 3.4386, cover loss of 0.4437, secret loss of 0.9983
# Training: Batch 52/66. Loss of 5.8453, cover loss of 0.6884, secret loss of 1.7190
# Training: Batch 53/66. Loss of 1.8271, cover loss of 0.9596, secret loss of 0.2892
# Training: Batch 54/66. Loss of 6.8738, cover loss of 0.6222, secret loss of 2.0839
# Training: Batch 55/66. Loss of 2.7545, cover loss of 0.7702, secret loss of 0.6615
# Training: Batch 56/66. Loss of 2.4899, cover loss of 0.9250, secret loss of 0.5216
# Training: Batch 57/66. Loss of 5.5000, cover loss of 0.7353, secret loss of 1.5882
# Training: Batch 58/66. Loss of 3.6045, cover loss of 0.5945, secret loss of 1.0033
# Training: Batch 59/66. Loss of 5.9857, cover loss of 0.6006, secret loss of 1.7950
# Training: Batch 60/66. Loss of 9.6280, cover loss of 0.7247, secret loss of 2.9678
# Training: Batch 61/66. Loss of 4.4678, cover loss of 0.8770, secret loss of 1.1969
# Training: Batch 62/66. Loss of 6.6219, cover loss of 0.2448, secret loss of 2.1257
# Training: Batch 63/66. Loss of 4.1043, cover loss of 0.1895, secret loss of 1.3050
# Training: Batch 64/66. Loss of 3.8610, cover loss of 0.1670, secret loss of 1.2314
# Process Process-1:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1d29419b5eb9> in <module>()
# ----> 1 net, mean_train_loss, loss_history = train_model(train_loader, val_loader, beta, learning_rate)
#
# <ipython-input-7-32b242f1c31a> in train_model(train_loader, val_loader, beta, learning_rate)
#      31             # Calculate loss and perform backprop
#      32             train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
# ---> 33             train_loss.backward()
#      34             optimizer.step()
#      35
#
# /usr/local/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     154                 Variable.
#     155         """
# --> 156         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     157
#     158     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %% [markdown]
# We test the model and print out a few images so we can visually see how good a job the model did.

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, 0.5)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data[0], loss_secret.data[0], loss_cover.data[0]))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.data[0])
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# Total loss: 0.51
# Loss on secret: 0.54
# Loss on cover: 0.24
# Total loss: 1.02
# Loss on secret: 1.06
# Loss on cover: 0.49
# Process Process-2:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 34, in _worker_loop
#     r = index_queue.get()
#   File "/usr/local/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     res = self._reader.recv_bytes()
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-be30202c04e5> in <module>()
#      19
#      20     # Compute output
# ---> 21     test_hidden, test_output = net(test_secret, test_cover)
#      22
#      23     # Calculate loss
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-4-3fd22fa03092> in forward(self, secret, cover)
#     180         mid = torch.cat((x_1, cover), 1)
#     181         x_2, x_2_noise = self.m2(mid)
# --> 182         x_3 = self.m3(x_2_noise)
#     183         return x_2, x_3
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# <ipython-input-4-3fd22fa03092> in forward(self, r)
#     162         mid = torch.cat((r1, r2, r3), 1)
#     163         r4 = self.finalR3(mid)
# --> 164         r5 = self.finalR4(mid)
#     165         r6 = self.finalR5(mid)
#     166         mid2 = torch.cat((r4, r5, r6), 1)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      65     def forward(self, input):
#      66         for module in self._modules.values():
# ---> 67             input = module(input)
#      68         return input
#      69
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/activation.py in forward(self, input)
#      41
#      42     def forward(self, input):
# ---> 43         return F.threshold(input, self.threshold, self.value, self.inplace)
#      44
#      45     def __repr__(self):
#
# /usr/local/lib/python3.6/site-packages/torch/nn/functional.py in threshold(input, threshold, value, inplace)
#     457
#     458 def threshold(input, threshold, value, inplace=False):
# --> 459     return _functions.thnn.Threshold.apply(input, threshold, value, inplace)
#     460
#     461
#
# /usr/local/lib/python3.6/site-packages/torch/nn/_functions/thnn/auto.py in forward(ctx, input, *params)
#     172             del ctx.buffers
#     173
# --> 174         getattr(ctx._backend, update_output.name)(ctx._backend.library_state, input, output, *args)
#     175         return output
#     176
#
# KeyboardInterrupt:
